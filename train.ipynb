# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from torch.utils.data import Dataset, DataLoader

import sys, os
sys.path.append('..')

from generator import *
from discriminator import *
from trainer import *
from hiragana_dataset import make_hiragana_dataset

# %%
DATADIR = "../data/hiragana73"

# %%
# DATADIR = "../data/hiragana73"
# CATEGORIES = ['a', 'i', 'u', 'e', 'o']

img_size = 48
# n_point = 20

# gen = Generator6(img_size, n_point, w_m=0.25, w_M=9.)
# disc = Discriminator3(img_size, n_point)

plotline = PlotLine2(img_size)

# %%
train_loss_list, validation_loss_list = train(gen, disc, DATADIR, CATEGORIES, batch_size=100, num_epochs=20, lr=0.001)
# Out:
# using: cpu
# ------------------------- Epoch 1 -------------------------
# Training
# 100%|██████████| 35/35 [00:50<00:00,  1.45s/it]
# Validating
# 100%|██████████| 15/15 [00:09<00:00,  1.55it/s]
# Training loss: 19474.5251
# Validation loss: 16969.8765
# ------------------------- Epoch 2 -------------------------
# Training
# 100%|██████████| 35/35 [00:54<00:00,  1.55s/it]
# Validating
# 100%|██████████| 15/15 [00:09<00:00,  1.61it/s]
# Training loss: 16467.5768
# Validation loss: 16254.3040
# ------------------------- Epoch 3 -------------------------
# Training
# 100%|██████████| 35/35 [00:51<00:00,  1.47s/it]
# Validating
# 100%|██████████| 15/15 [00:09<00:00,  1.56it/s]
# Training loss: 16074.0392
# Validation loss: 15299.1380
# ------------------------- Epoch 4 -------------------------
# Training
# 100%|██████████| 35/35 [00:50<00:00,  1.45s/it]
# Validating
# 100%|██████████| 15/15 [00:08<00:00,  1.73it/s]
# Training loss: 15572.3914
# Validation loss: 15505.3332
# ...

# %%
torch.save(gen, 'gen6_0107.pth')

# %%
plt.plot(train_loss_list, label='train')
plt.plot(validation_loss_list, label='validation')
plt.legend()

# %%
train_dataset, valid_dataset = make_hiragana_dataset(DATADIR, CATEGORIES=['a'])
# バッチサイズの指定
batch_size = 1
# DataLoaderを作成
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# 動作確認
# イテレータに変換
batch_iterator = iter(train_dataloader)

# %%
# 1番目の要素を取り出す
inputs, labels = next(batch_iterator)
sns.heatmap(labels.detach().numpy()[0])
plt.show()

# %%
xyw = gen(inputs)
line = plotline(xyw)
sns.heatmap(line.detach().numpy()[0])
plt.show()

# %%
xy = xyw.detach().numpy()[0, :, 0:2]

fig, ax = plt.subplots(1,1)
ax.set_xlim(0, 48)
ax.set_ylim(0, 48)
ax.invert_yaxis()
ax.grid()
ax.plot(xy[:, 1], xy[:, 0], marker='o')
plt.show()

# %%
distance_log = disc.distance_log
error_log = disc.error_log

plt.plot(distance_log, label='distance')
plt.plot(error_log, label='error')
plt.legend()

# %%
plt.plot(distance_log, label='distance')

# %%
a_gen = Generator6(img_size, n_point, w_m=0.25, w_M=9.)
#losses, errors, distances = train1(a_gen, disc, inputs, labels, iteration=2000, lr=0.1)

# %%
a_gen.state_dict
# Out:
# <bound method Module.state_dict of Generator6(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (conv1): Conv2d(3, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(3, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(3, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=108, out_features=84, bias=False)
#   (fc2): Linear(in_features=84, out_features=60, bias=False)
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
#   (bn2d): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn1d): BatchNorm1d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )>

# %%
a_gen.load_state_dict(torch.load('gen_a_params.pth', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
gen8 = Generator8(w_m=0., w_M=4.)
disc3 = Discriminator3(img_size=48)

# %%
losses, errors, distances = train1(gen8, disc3, inputs, labels, iteration=2000, lr=0.1)
# Out:
# using: cpu
# iter: 0, loss: 17623.298828125
# iter: 100, loss: 6094.20166015625
# iter: 200, loss: 6320.50341796875
# iter: 300, loss: 3192.98193359375
# iter: 400, loss: 3025.988525390625
# iter: 500, loss: 1716.047607421875
# iter: 600, loss: 2231.312744140625
# iter: 700, loss: 1466.0599365234375
# iter: 800, loss: 1887.11376953125
# iter: 900, loss: 1011.224853515625
# iter: 1000, loss: 1089.069580078125
# iter: 1100, loss: 905.3013916015625
# iter: 1200, loss: 1243.3133544921875
# iter: 1300, loss: 1173.0836181640625
# iter: 1400, loss: 1137.69140625
# iter: 1500, loss: 1512.7679443359375
# iter: 1600, loss: 1003.7056884765625
# iter: 1700, loss: 1005.4970092773438
# iter: 1800, loss: 1363.1533203125
# iter: 1900, loss: 844.127685546875

# %%
# a_gen = a_gen.eval()
xyw = gen8(inputs)
line = plotline(xyw)
sns.heatmap(line.detach().numpy()[0])
plt.show()

# %%
xy = xyw.detach().numpy()[0, :, 0:2]

fig, ax = plt.subplots(1,1)
ax.set_xlim(0, 48)
ax.set_ylim(0, 48)
ax.invert_yaxis()
ax.grid()
ax.plot(xy[:, 1], xy[:, 0], marker='o')
plt.show()

# %%
gen8_ = Generator8(w_m=0., w_M=4.)
disc5 = Discriminator5(img_size=48)
losses, errors, distances = train1(gen8_, disc5, inputs, labels, iteration=2000, lr=0.1)
# Out:
# using: cpu
# iter: 0, loss: 3579450.5
# iter: 100, loss: 97593.9140625
# iter: 200, loss: 87884.2890625
# iter: 300, loss: 86712.09375
# iter: 400, loss: 87584.859375
# iter: 500, loss: 88948.84375
# iter: 600, loss: 87316.234375
# iter: 700, loss: 89901.6640625
# iter: 800, loss: 85810.8984375
# iter: 900, loss: 85752.0390625
# iter: 1000, loss: 83631.015625
# iter: 1100, loss: 83804.8125
# iter: 1200, loss: 84258.9453125
# iter: 1300, loss: 83778.0078125
# iter: 1400, loss: 82776.34375
# iter: 1500, loss: 83448.8984375
# iter: 1600, loss: 84543.984375
# iter: 1700, loss: 84818.421875
# iter: 1800, loss: 83333.3359375
# iter: 1900, loss: 82921.109375

# %%
xyw_ = gen8_(inputs)
line_ = plotline(xyw_)
sns.heatmap(line_.detach().numpy()[0])
plt.show()

# %%
xy_ = xyw_.detach().numpy()[0, :, 0:2]

fig, ax = plt.subplots(1,1)
ax.set_xlim(0, 48)
ax.set_ylim(0, 48)
ax.invert_yaxis()
ax.grid()
ax.plot(xy_[:, 1], xy_[:, 0], marker='o')
plt.show()

# %%
plt.plot(losses)

# %%
plt.plot(distances)

# %%
plt.plot(errors)
plt.plot([distance*1000 for distance in distances])

# %%
xyw_ = gen8(torch.randn_like(inputs))
line_ = plotline(xyw_)
sns.heatmap(line_.detach().numpy()[0])
plt.show()
